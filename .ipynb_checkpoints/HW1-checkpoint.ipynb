# %% [markdown]
# # BME4760 HW1

# %% [markdown]
# ## Loading Data
# Loading the necessary libraries in order to preprocess and plot:<br>
# numpy   | Arrays <br>
# urllib  | Opening URLS <br>
# pandas  | Data structure organization <br>
# matplot | Plotting and Figures <br>
# seaborn | Even more plotting capabilities <br>

# %%
# Downloading the Post-Operative Patient Data Set
# http://archive.ics.uci.edu/ml/datasets/Post-Operative+Patient
import numpy as np
from urllib.request import urlopen
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading the data from the URL path as a data frame and giving the dataframe column names once it is imported with 'names' array.

# %%
# URL path for Post-Operative Dataset
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/postoperative-patient-data/post-operative.data'

# Downloading File and Loading Dataset
names = ['L-CORE','L-SURF','L-02','L-BP','SURF-STBL','CORE-STBL','BP-STBL','COMFORT','decision ADM-DECS']
df = pd.read_csv(url,names=names)

# %% [markdown]
# > OPTIONAL display so I could see all the rows and confirm the missing values

# %%
# Displays all rows by increasing display limit
pd.options.display.max_rows=100

# %% [markdown]
# ## Pre-processing Data
# I opted to do the preprocessing first due to the unknown '?' values in the initial data frame. While it would still plot, it would be better to view the relationships without the unknown values. Therefore, I removed the rows where '?' were present. This wouldn't impact the results too much since there are only 3 missing values in the COMFORT column.

# %%
# Removing rows with missing variables
# Replacing '?' with NaN, then dropping rows with NaN
df_Processed = df.replace({'?':np.nan}).dropna()

# Replacing a weird A with a space after it
# Without this, it plots 'A ' as its own row
df_Processed = df_Processed.replace({'A ':'A'})

# Converting COMFORT string values into numeric values to plot
# through seaborn properly. Without this, the order of COMFORT
# is out of order
df_Processed["COMFORT"] = pd.to_numeric(df_Processed["COMFORT"])

# Printing shapes and the pre-processed table
# proves the removal of 3 rows
print(df.shape)
print(df_Processed.shape)
df_Processed
# Out:
# (90, 9)
# (87, 9)
#    L-CORE L-SURF       L-02  L-BP SURF-STBL   CORE-STBL     BP-STBL  COMFORT  \
# 0     mid    low  excellent   mid    stable      stable      stable       15
# 1     mid   high  excellent  high    stable      stable      stable       10
# 2    high    low  excellent  high    stable      stable  mod-stable       10
# 3     mid    low       good  high    stable    unstable  mod-stable       15
# 4     mid    mid  excellent  high    stable      stable      stable       10
# 5    high    low       good   mid    stable      stable    unstable       15
# 6     mid    low  excellent  high    stable      stable  mod-stable        5
# 7    high    mid  excellent   mid  unstable    unstable      stable       10
# 8     mid   high       good   mid    stable      stable      stable       10
# 9     mid    low  excellent   mid  unstable      stable  mod-stable       10
# 10    mid    mid       good   mid    stable      stable      stable       15
# 11    mid    low       good  high    stable      stable  mod-stable       10
# 12   high   high  excellent  high  unstable      stable    unstable       15
# 13    mid   high       good   mid  unstable      stable  mod-stable       10
# 14    mid    low       good  high  unstable    unstable      stable       15
# 15   high   high  excellent  high  unstable      stable    unstable       10
# 16    low   high       good  high  unstable      stable  mod-stable       15
# 17    mid    low       good  high  unstable      stable      stable       10
# 18    mid   high       good   mid  unstable      stable    unstable       15
# 19    mid    mid       good   mid    stable      stable      stable       10
# 20    low   high       good   mid  unstable      stable      stable       15
# 21    low    mid  excellent  high  unstable      stable    unstable       10
# 22    mid    mid       good   mid  unstable      stable    unstable       15
# 23    mid    mid       good   mid  unstable      stable      stable       10
# 24   high   high       good   mid    stable      stable  mod-stable       10
# 25    low    mid       good   mid  unstable      stable      stable       10
# 26   high    mid       good   low    stable      stable  mod-stable       10
# 27    low    mid  excellent  high    stable      stable  mod-stable       10
# 28    mid    mid  excellent   mid    stable      stable    unstable       15
# 29    mid    mid       good   mid  unstable      stable    unstable       10
# 30    mid    mid       good  high  unstable      stable      stable       10
# 31    low    low       good   mid  unstable      stable    unstable       10
# 32    mid    mid  excellent  high  unstable      stable  mod-stable       10
# 33    mid    low       good   mid    stable      stable      stable       10
# 34    low    mid  excellent  high    stable      stable  mod-stable       10
# 35    mid    mid       good   mid    stable      stable      stable       10
# 36    low    mid  excellent   mid    stable      stable      stable       10
# 37    low    low       good   mid  unstable      stable    unstable       10
# 38    low    low       good   mid    stable      stable      stable        7
# 39    mid    mid       good  high  unstable      stable  mod-stable       10
# 40    low    low       good   mid  unstable      stable      stable       10
# 41    low    mid       good   mid    stable      stable      stable       15
# 42   high   high       good  high  unstable      stable      stable       15
# 43    mid    mid       good   mid    stable      stable      stable       10
# 44    low    low  excellent   mid    stable      stable      stable       10
# 45    low    mid       good   mid  unstable      stable      stable       10
# 47    mid    mid  excellent   mid  unstable      stable      stable       10
# 49    mid   high       good   low  unstable      stable      stable       10
# 50    mid   high       good   mid  unstable  mod-stable  mod-stable       10
# 51    low   high  excellent   mid  unstable      stable      stable       10
# 52    mid    low  excellent  high  unstable      stable    unstable       10
# 53    mid    mid       good   mid  unstable      stable  mod-stable       10
# 54   high   high  excellent   mid  unstable      stable  mod-stable       10
# 55    mid    mid       good   mid  unstable      stable      stable       15
# 56   high    mid       good  high    stable      stable    unstable       15
# 57    mid    low       good  high  unstable      stable  mod-stable       10
# 58    low    low       good  high    stable      stable      stable       10
# 59    mid   high       good   mid    stable      stable  mod-stable       10
# 60    mid   high       good   mid  unstable      stable    unstable       10
# 61    mid    low  excellent  high    stable      stable      stable       10
# 62    mid    mid       good   mid    stable      stable    unstable       10
# 63    mid    low  excellent   mid    stable      stable    unstable       10
# 64   high    mid  excellent   mid  unstable    unstable    unstable       10
# 65    mid    mid       good  high    stable      stable      stable       10
# 66    mid    low  excellent   mid  unstable      stable      stable       10
# 67    mid    mid  excellent   mid  unstable      stable      stable       10
# 68    mid    mid  excellent  high    stable      stable      stable       10
# 69    mid    mid  excellent   low    stable      stable      stable       10
# 71    low    low  excellent   mid    stable      stable      stable       10
# 72    mid    mid  excellent   mid    stable      stable  mod-stable       10
# 73    mid    mid  excellent  high    stable      stable      stable       10
# 74    mid    low  excellent  high    stable      stable  mod-stable       10
# 75    low    mid       good   mid    stable      stable    unstable       10
# 76    mid    mid  excellent   mid    stable      stable  mod-stable       10
# 77    mid    mid  excellent   mid    stable      stable    unstable       10
# 78    mid    mid  excellent   mid  unstable    unstable      stable       10
# 79    mid    mid       good  high    stable      stable      stable       10
# 80    mid    mid  excellent   mid    stable      stable      stable       15
# 81    mid    mid  excellent   mid    stable      stable      stable       10
# 82    mid    low       good   mid    stable      stable    unstable       10
# 83   high    mid  excellent   mid  unstable      stable    unstable        5
# 84    mid    mid  excellent   mid    stable      stable    unstable       10
# 85    mid    mid  excellent   mid  unstable      stable      stable       10
# 86    mid    mid  excellent   mid  unstable      stable      stable       15
# 87    mid    mid       good   mid  unstable      stable      stable       15
# 88    mid    mid  excellent   mid  unstable      stable      stable       10
# 89    mid    mid       good   mid  unstable      stable      stable       15
#
#    decision ADM-DECS
# 0                  A
# 1                  S
# 2                  A
# 3                  A
# 4                  A
# 5                  S
# 6                  S
# 7                  S
# 8                  S
# 9                  S
# 10                 A
# 11                 A
# 12                 A
# 13                 A
# 14                 S
# 15                 A
# 16                 A
# 17                 A
# 18                 A
# 19                 A
# 20                 A
# 21                 S
# 22                 A
# 23                 A
# 24                 A
# 25                 A
# 26                 A
# 27                 A
# 28                 A
# 29                 S
# 30                 A
# 31                 A
# 32                 A
# 33                 A
# 34                 A
# 35                 A
# 36                 S
# 37                 S
# 38                 S
# 39                 A
# 40                 A
# 41                 S
# 42                 S
# 43                 S
# 44                 A
# 45                 S
# 47                 A
# 49                 A
# 50                 A
# 51                 A
# 52                 A
# 53                 S
# 54                 A
# 55                 A
# 56                 A
# 57                 A
# 58                 A
# 59                 A
# 60                 A
# 61                 A
# 62                 A
# 63                 S
# 64                 A
# 65                 S
# 66                 A
# 67                 A
# 68                 A
# 69                 A
# 71                 A
# 72                 S
# 73                 A
# 74                 A
# 75                 A
# 76                 A
# 77                 A
# 78                 S
# 79                 A
# 80                 A
# 81                 S
# 82                 I
# 83                 A
# 84                 A
# 85                 A
# 86                 S
# 87                 A
# 88                 A
# 89                 S

# %% [markdown]
# ## Plotting relationships
# I used <b>seaborn</b> library for this relationship plotting. Specifically a categorical graphing method for graphing the relationships of categories among a scale. A new figure is made for each plot and uses the processed data from the previous section. The order for each was based on the <b>"post-operative.names"</b> file. Counting the individual patients with each categorical feature isn't as significant since the connection between the categorical feature and COMFORT is what we want to evaluate.
# <br>
# ### Interpretations
# L-CORE    | Patient's Internal Temperature in C        |<br>
# L-SURF    | Patient's Surface Temperature in C         |<br>
# L-02      | Oxygen Saturation in %                     |<br>
# L-BP      | Last Measurement of Blood Pressure         |<br>
# SURF-STBL | Stability of Patient's Surface Temperature |<br>
# CORE-STBL | Stability of Patient's Core Temperature    |<br>

# %%
sns.set(style="ticks", color_codes=True)
plt.figure()
sns.swarmplot(x="L-CORE", y="COMFORT", data=df_Processed, orient="v", order = ["high","mid","low"])
plt.figure()
sns.swarmplot(x="L-SURF", y="COMFORT", data=df_Processed, orient="v", order = ["high","mid","low"])
plt.figure()
sns.swarmplot(x="L-02", y="COMFORT", data=df_Processed, orient="v", order = ["excellent","good","fair","poor"])
plt.figure()
sns.swarmplot(x="L-BP", y="COMFORT", data=df_Processed, orient="v", order = ["high","mid","low"])
plt.figure()
sns.swarmplot(x="SURF-STBL", y="COMFORT", data=df_Processed, orient="v", order = ["stable","mod-stable","unstable"])
plt.figure()
sns.swarmplot(x="CORE-STBL", y="COMFORT", data=df_Processed, orient="v", order = ["stable","mod-stable","unstable"])
plt.figure()
sns.swarmplot(x="BP-STBL", y="COMFORT", data=df_Processed, orient="v", order = ["stable","mod-stable","unstable"])
plt.figure()
sns.swarmplot(x="decision ADM-DECS", y="COMFORT", data=df_Processed, orient="v", order = ["I","S","A"])
